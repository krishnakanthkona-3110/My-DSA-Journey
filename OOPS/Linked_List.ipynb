# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakanthkona-3110/My-DSA-Journey/blob/main/OOPS/Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linked List-1
#
# https://notability.com/n/0dXaJh66dEePgJ7nVdsrhK

# %% [markdown]
# # Why OOPS is required?
#
# OOP is required to handle complexity in large applications. It allows us to group related data and functions into objects, which improves code organization and modularity. It supports reusability through inheritance, data security through encapsulation, and flexibility through polymorphism. This makes the system easier to maintain, extend, and scale. OOP also helps in representing real-world entities like customers, accounts, or vehicles directly in code, which makes design more intuitive.
#
#
# --- OOP is like organizing files into folders instead of keeping everything loose. It makes management easier.

# %% [markdown]
# # Dunder Methods:-
# Dunder methods are special methods in Python that allow objects to define and control their behavior with built-in operations like printing, addition, length, etc.

# %% [markdown]
# Most Important Dunder Methods (Interview Focus)
# 1. init
#
# Constructor
#
# def __init__(self):
#
#
# Runs when object created
#
# 2. str
#
# Controls print()
#
# print(obj)
#
# 3. len
#
# Controls len()
#
# len(obj)
#
# 4. add
#
# Controls + operator
#
# Example:
#
#
# class Number:
#
#     def __init__(self, x):
#         self.x = x
#
#     def __add__(self, other):
#         return self.x + other.x
#
# a = Number(5)
#
# b = Number(10)
#
# print(a + b)
#
#
# Output:
#
# 15

# %% [markdown]
# Real Meaning of "Magic"
#
# Python automatically calls them.
#
# You don't call them directly usually.
#
# Why called Dunder?
#
# Because:
#
# Double UNDERSCORE
#
# dunder = double underscore

# %% [markdown]
# OOPS Concepts in detail  -https://www.w3schools.com/python/python_oop.asp
#
#
# https://www.geeksforgeeks.org/python/python-oops-concepts/

# %%
class Book:
  title = ''
  authors = ''

  def read(self):
    return 'Reading a book' + self.title

  def authorname(self):
    return 'Author name is ' + self.authors

# %% [markdown]
# # parenthesis is used for function

# %%
b1=Book()
b1.title = 'The Toxic'
b1.authors = 'James'

b2 = Book()
b2.title = 'Learn the python'
b2.authors = "Trump"

# %%
b2.authorname()
# Out:
# 'Author name is Trump'

# %% [markdown]
# # We have two types of memory,
# Stack and Heap
#
# In Heap the class is created

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Both a and b point to same object.
#
# # Objects are stored in Heap
#
# # References are stored in Stack

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Self is a reference to the object created.
# In that object, dictionary is created to store variables as key value pairs.)
#
# self refers to the current object (instance) of the class. It is used to access the variables and methods stored in that object's memory.

# %% [markdown]
# # Self - address of object on which function needs to be executed

# %% [markdown]
# Constructor(one of magic methods) - they are called automatically when object is created

# %%
class Student:
  def __init__(self, n,a,m):
    self.name = n
    self.age = a
    self.marks = m
    print(self)

  def calculate_grade(self):
    print(self)
    if self.marks > 90:
      return 'A'
    else:
      return 'B'

# %%
s1 = Student('Him',13,90)
print(s1)
s2 = Student('Hqim',13,90)
print(s2)

# %%
s1.calculate_grade()
# Out:
# ...
# 'B'

# %% [markdown]
# # Key Concept (MOST IMPORTANT)
#
# There is only ONE object created.
#
# These are just different references to same object:

# %% [markdown]
# b1 = b2
#
# # Shallow copy - If both b1 and b2 Variables storing the same addresses
# # Deep copy - If b1, and b2 taking same values but different addresses

# %% [markdown]
# # Linked List
# A linked list consists of nodes with some sort of data, and a pointer, or link, to the next node.

# %% [markdown]
# # 1) Print Linked List
#
# You are given A which is the head of a linked list. Print the linked list in space separated manner.
#
# Note : The last node value must also be succeeded by a space and after printing the entire list you should print a new line
#
#
# Example Input
#
# Input 1:
# A = 1 -> 2 -> 3
#
# Example Output
#
# Output 1:
# 1 2 3

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

n1 = Node(10)
n2 = Node(20)
n3 = Node(30)
n4 = Node(40)

n1.next = n2
n2.next = n3
n3.next = n4

# %%
currentnode = n1

while currentnode is not None:
  print(currentnode.data, end="->")

  currentnode = currentnode.next

print('null')
# Out:
# 10->20->30->40->null

# %% [markdown]
# # 2) kth Node in a List
# You are given a singly linked list and an integer k. Your task is to access the node at the k-th index (0-based indexing) in the list and return its value. If the index is out of bounds, return -1.

# %%
def solve(A,k):
  index = 0
  current = A

  while current is not None:
    if index ==k:
      return current.data
    current = current.next
    index += 1
  return -1

# %%
solve(n1,2)
# Out:
# 30

# %% [markdown]
# Time Complexity: O(N)
#
# Space Complexity: O(1)
#
# We traverse the linked list node by node until we reach index k or the end, so the time complexity is O(N) in the worst case. We are not using any extra space except a few variables, so the space complexity is O(1)

# %% [markdown]
# # 3) Insert in Linked List
#
# You are given A which is the head of a linked list. Also given is the value B and position C. Complete the function that should insert a new node with the said value at the given position.
#
# Notes:
#
# In case the position is more than length of linked list, simply insert the new node at the tail only.
#
# In case the pos is 0, simply insert the new node at head only.
#
# Follow 0-based indexing for the node numbering.

# %%
def insert(A,B,C):

  new_node = Node(B)

  # Empty list
  if A is None:
    return new_node

  # Case 1: Insert at head
  if C == 0:
    new_node.next = A #head
    return new_node

  current = A
  index = 0

  # Traverse until position before C
  while current.next is not None and index < (C-1):
    current = current.next
    index +=1

    # save next node
    save = current.next

    # Insert new node
    current.next = new_node

    # Connect remaining list
    new_node.next = save

    return A

# %%
insert(n1, 11,2)

# %% [markdown]
# # Just for learning - If we ignore if A is None: return new_node
# This error means your head A is None (empty linked list) and your code is trying to access:
#
# current.next
#
# But if current = None, then:
#
# None.next ❌ ERROR
# ✅ Why this happens
#
# Your code probably has:
#
# current = A
#
# while current.next is not None and index < (C-1):
#
# If:
#
# A = None
#
# Then:
#
# current = None
#
# So:
#
# current.next ❌ AttributeError

# %% [markdown]
# Refresher-
#
# To reach 3rd node = 2 jumps
#
# To reach kth node = (k-1) jumps

# %% [markdown]
# # 4Q) Delete in Linked List
#
# You are given the head of a linked list A and an integer B. Delete the B-th node from the linked list.
#
# Note : Follow 0-based indexing for the node numbering.

# %%
def delete(A,B):

  # Case 1: Empty list
  if A is None:
    return None

  # Case 2: Delete head
  if B == 0:
    return A.next

# Traverse to node before position B
  current = A
  index = 0
  while current.next is not None and index < (B-1):
      current = current.next
      index += 1

 # Delete only if node exists
  if current.next is not None:
    save = current.next
    current.next = current.next.next

  return A

# %% [markdown]
# The while loop ensures safe traversal, but it does not guarantee that the node to delete exists. The additional check ensures we do not attempt to access .next of None, preventing runtime errors when B is out of bounds.

# %% [markdown]
# # 5Q). Reverse Linked List
#
# You are given a singly linked list having head node A. You have to reverse the linked list and return the head node of that reversed list.
#
# NOTE: You have to do it in-place and in one-pass.

# %%
def reverse( A):

        # prev will become the new head of reversed list
        # Initially there is no previous node
        prev = None

        # current starts from head of original list
        current = A

        # Traverse the entire linked list
        while current is not None:

            # Step 1: Save the next node
            # Because we are going to break the link
            next_node = current.next

            # Step 2: Reverse the link
            # Instead of pointing to next node,
            # current will point to previous node
            current.next = prev

            # Step 3: Move prev forward
            # prev becomes current node
            prev = current

            # Step 4: Move current forward
            # current becomes next node (original next)
            current = next_node

        # When loop ends:
        # prev will be pointing to new head
        return prev

# %%
reverse(n1)

# %% [markdown]
# Time Complexity: O(N)
#
#
# You traverse the linked list only once
#
# If there are N nodes, the loop runs N times
#
#
# Time = O(N)
# 📦 Space Complexity: O(1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def reversed(A):

    prev = None
    current = A

    while current is not None:
        # store next
        next_node = current.next

        # important # reverse current node's next pointer
        current.next = prev

        # move pointers one position ahead
        prev = current
        current = next_node

    return prev

# %%
reversed(n1)

# %% [markdown]
# # Linked List-2
#
# https://notability.com/n/13589hk6S2Kufoh4R0n3ra

# %% [markdown]
# # 6Q). Middle element of linked list
# Given a linked list of integers, find and return the middle element of the linked list.
#
#
#
# NOTE: If there are N nodes in the linked list and N is even then return the (N/2 + 1)th element.

# %%
def middle(A):

  current = A
  count = 0

  # Step 1: Count nodes
  while current:
    count += 1
    current = current.next

  # Step 2: Find middle position # This automatically gives (N/2 + 1) for even case
  mid = count//2

  # Step 3: Traverse to middle
  current = A
  for _ in range(mid):
    current = current.next

  return current.data

# %%
middle(n1)
# Out:
# 10

# %% [markdown]
# First I count total nodes, then compute the middle index, and finally traverse again to return that node.
#
# Time Complexity = O(N) + O(N) = O(N)
#
# Space Complexity = O(1)

# %%
def middleop(A):

  slow = A
  fast = A

  while fast and fast.next is not None:

    # Move slow pointer by 1 step
    slow = slow.next

    # Move fast pointer by 2 steps
    fast = fast.next.next

  return slow.data

# %%
middleop(n1)
# Out:
# 10

# %% [markdown]
# use slow and fast pointers. Fast moves two steps while slow moves one. When fast reaches the end, slow will be at the required middle node.
#
# the loop runs about N/2 times
#
# Time Complexity O(N\2) = O(N)

# %% [markdown]
# # 7Q). Check whether a singly linked list is a palindrome.

# %%
def palindrome(A):

    # Edge case: empty or single node
    if not A or not A.next:
        return 1

    # Step 1: Find middle
    slow = A
    fast = A

    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next

    # Step 2: Reverse second half
    prev = None
    current = slow

    while current:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node

    # Step 3: Compare first half and reversed second half
    first = A
    second = prev

    while second:
        if first.data != second.data:
            return 0
        first = first.next
        second = second.next

    return 1

# %%
palindrome(n1)
# Out:
# 0

# %% [markdown]
# 🔹 Step 1: Find Middle
#
# Using slow & fast pointer → traverse list once
# ⏱ O(N)
#
# 🔹 Step 2: Reverse Second Half
#
# Reversing half of list
# ⏱ O(N/2)
#
# 🔹 Step 3: Compare Both Halves
#
# Again traverse half
# ⏱ O(N/2)
#
# 🔥 Total Time:
#
# O(N)+O(N/2)+O(N/2)
# =
# =O(2N)
#
# =O(N)
#
# 👉 Final Time Complexity = O(N)

# %% [markdown]
# In odd length, the slow pointer stops exactly at the middle. When we reverse from slow, the middle element gets included in comparison, but since it compares with itself, it does not affect correctness.

# %%
# 2nd method, which skips the comparison of middle element for odd length

def palindrome(A):

    if not A or not A.next:
        return 1

    slow = A
    fast = A

    # Find middle
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next

    # Skip middle for odd length
    if fast:
        slow = slow.next

    # Reverse second half
    prev = None
    current = slow

    while current:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node

    # Compare halves
    first = A
    second = prev

    while second:
        if first.val != second.val:
            return 0
        first = first.next
        second = second.next

    return 1

# %% [markdown]
# # 8Q). Merge Two Sorted Lists
#
# Merge two sorted linked lists, A and B, and return it as a new list.
#
#
#
#
# The new list should be made by splicing together the nodes of the first two lists and should also be sorted.

# %%
'''class ListNode:
  def __init__(self,val=0,next=None):
    self.val = val
    self.next = next'''

def merge(list1,list2):

  # If one list is empty
  if list1 is None:
    return list2

  if list2 is None:
    return list1

  # Initialize head and tail of merged list
  if list1.val < list2.val:
    head = tail = list1
    list1 = list1.next

  else:
    head = tail = list2
    list2 = list2.next

  # Merge remaining nodes
  while list1 is not None and list2 is not None:

    if list1.val < list2.val:
      tail.next = list1
      tail = list1
      list1 = list1.next


    else:
      tail.next = list2
      tail = list2
      list2 = list2.next

  # Attach remaining nodes
  if list1 is None:
    tail.next = list2
  else:
    tail.next = list1

  return head

# %%
# check for condition to verify

# %% [markdown]
# Time → O(N + M)
#
# Space → O(1)

# %% [markdown]
# # The below method is simple, in my view
# # 2 nd Method

# %%
class ListNode:
  def __init__(self,val=0,next=None):
    self.val = val
    self.next = next

class Solution:
  def merge_two_lists(self,list1,list2):
    dummy = ListNode()
    curr = dummy

    while list1 and list2:
      if list1.val < list2.val:
        curr.next = list1
        curr = list1
        list1 = list1.next

      else:
        curr.next = list2
        curr = list2
        list2 = list2.next

    curr.next = list1 if list1 else list2

    return dummy.next

# %% [markdown]
# # 9Q). Sort List
#
# Sort a linked list, A in O(n log n) time.

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

n1 = ListNode(1)
n2 = ListNode(2)
n3 = ListNode(3)
n4 = ListNode(4)

n1.next = n2
n2.next = n3
n3.next = n4

# %%
class Solution:
    def sortList(self, head):
        # Base case
        if head is None or head.next is None:
            return head

        # Find middle
        slow = head
        fast = head.next
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

        mid = slow.next
        slow.next = None  # break the list

        # Recursively sort both halves
        left = self.sortList(head)
        right = self.sortList(mid)

        # Merge them
        return self.merge(left, right)

    # 👇 HERE is the merge function
    def merge(self, l1, l2):
        dummy = ListNode()
        tail = dummy

        while l1 and l2:
            if l1.val < l2.val:
                tail.next = l1
                l1 = l1.next
            else:
                tail.next = l2
                l2 = l2.next
            tail = tail.next

        # attach remaining nodes
        tail.next = l1 if l1 else l2

        return dummy.next

# %%
s1 = Solution()

# %%
s1.sortList(n1)

# %%
currentnode = s1.sortList(n1)

while currentnode is not None:
  print(currentnode.val, end="->")

  currentnode = currentnode.next

print('null')
# Out:
# 1->2->3->4->null

# %% [markdown]
# Time Complexity:
# - The algorithm divides the list into halves recursively until each sublist contains only one node, which takes O(log n) divisions.
# - Each level of recursion involves merging pairs of sorted lists, which collectively processes all nodes once per level.
# - Merging two lists takes O(n) time in total across all merges at each level.
# - Overall, the total time complexity is O(n log n), where n is the number of nodes in the list.
#
# Space Complexity:
# - The algorithm sorts the list in place, using only a constant amount of extra space for pointers and temporary variables.
# - However, due to recursion, there is a call stack that can go as deep as O(log n) in the worst case.
# - Therefore, the auxiliary space complexity is O(log n) because of the recursive call stack.
#
# In summary:
#
# Time complexity: O(n log n)
#
# Space complexity: O(log n)

# %% [markdown]
# # Doubly linked list

# %% [markdown]
# # For double linked list, learn the below:-
#   1 - Inserting at tail
#
#   2 - Deleting at head
#
#   3 - Reverse DLL

# %%
class DoublyNode:
  def __init__(self,val,next=None, prev=None):
    self.val = val
    self.next = next
    self.prev = prev

  def __str__(self):
    return str(self.val)

# %%
head = tail = DoublyNode(1)
print(tail)
print(head)
# Out:
# 1
# 1

# %% [markdown]
# DLL allows:
#
# Delete node in O(1)
#
# Insert at head in O(1)

# %% [markdown]
# # LRU Cache - LRU = Least Recently Used
#
# An LRU Cache removes the item that was used the longest time ago when the cache becomes full.
#
# 🧠 Simple Real-Life Example
#
# Think of:
#
# Browser tabs
#
# App switching in mobile
#
# Memory management in OS
#
# If memory is full → the system removes the least recently used item.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, key, value):
        self.key = key
        self.value = value
        self.prev = None
        self.next = None


class LRUCache:
    def __init__(self, capacity: int):
        self.capacity = capacity
        self.cache = {}
        self.head = Node(-1, -1)
        self.tail = Node(-1, -1)
        self.head.next = self.tail
        self.tail.prev = self.head

    def _add(self, node: Node):

        # Add a node right after the head
        # (most recently used position).
        next_node = self.head.next
        self.head.next = node
        node.prev = self.head
        node.next = next_node
        next_node.prev = node

    def _remove(self, node: Node):

       # emove a node from the
        # doubly linked list.
        prev_node = node.prev
        next_node = node.next
        prev_node.next = next_node
        next_node.prev = prev_node

    def get(self, key: int) -> int:
        # Get the value for a given key
        if key not in self.cache:
            return -1

        node = self.cache[key]
        self._remove(node)
        self._add(node)
        return node.value

    def put(self, key: int, value: int):

        #Put a key-value pair into the cache.
        if key in self.cache:
            node = self.cache[key]
            self._remove(node)
            del self.cache[key]

        if len(self.cache) >= self.capacity:

            # Remove the least recently used item
            # (just before the tail)
            lru_node = self.tail.prev
            self._remove(lru_node)
            del self.cache[lru_node.key]

        # Add the new node
        new_node = Node(key, value)
        self._add(new_node)
        self.cache[key] = new_node

# %%
# o

# %% [markdown]
# # LRU Cache
# Design and implement a data structure for Least Recently Used (LRU) cache. It should support the following operations: get and set.
#
# get(key) - Get the value (will always be positive) of the key if the key exists in the cache, otherwise return -1.
# set(key, value) - Set or insert the value if the key is not already present. When the cache reaches its capacity, it should invalidate the least recently used item before inserting the new item.
# The LRUCache will be initialized with an integer corresponding to its capacity. Capacity indicates the maximum number of unique keys it can hold at a time.
#
# Definition of "least recently used" : An access to an item is defined as a get or a set operation of the item. "Least recently used" item is the one with the oldest access time.
#
# NOTE: If you are using any global variables, make sure to clear them in the constructor.

# %%
class Node:
    def __init__(self, key, value):
        self.key = key
        self.value = value
        self.prev = None
        self.next = None


class LRUCache:
    def __init__(self, capacity):
        self.capacity = capacity
        self.cache = {}   # key -> node

        # Dummy head and tail
        self.head = Node(0, 0)
        self.tail = Node(0, 0)

        self.head.next = self.tail
        self.tail.prev = self.head

    # Remove node from DLL
    def _remove(self, node):
        node.prev.next = node.next
        node.next.prev = node.prev

    # Insert node right after head (MRU position)
    def _insert(self, node):
        node.next = self.head.next
        node.prev = self.head

        self.head.next.prev = node
        self.head.next = node

    # Get operation
    def get(self, key):
        if key not in self.cache:
            return -1

        node = self.cache[key]

        # Move accessed node to front (MRU)
        self._remove(node)
        self._insert(node)

        return node.value

    # Set operation
    def set(self, key, value):

        if key in self.cache:
            # Update existing node
            node = self.cache[key]
            node.value = value

            self._remove(node)
            self._insert(node)

        else:
            # If full, remove LRU (node before tail)
            if len(self.cache) == self.capacity:
                lru = self.tail.prev
                self._remove(lru)
                del self.cache[lru.key]

            # Insert new node
            new_node = Node(key, value)
            self.cache[key] = new_node
            self._insert(new_node)
