# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakanthkona-3110/My-DSA-Journey/blob/main/Graphs/DSA_Graphs_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://scaler-production-new.s3.ap-southeast-1.amazonaws.com/attachments/attachments/000/400/190/original/Graphs__21_Feb_2026.pdf?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIDNNIRGHAQUQRWYA%2F20260418%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Date=20260418T164324Z&X-Amz-Expires=561600&X-Amz-SignedHeaders=host&X-Amz-Signature=ff6952654ca886529d87521ebe86c4685a27cd80ea6308eb0ea19dcc22c81e62

# %% [markdown]
# #Prim's Algorithm
# Prim's algorithm finds the Minimum Spanning Tree (MST) in a connected and undirected graph.
#
# How it works:
#
# 1. Choose a random vertex as the starting point, and include it as the first vertex in the MST.
#
# 2. Compare the edges going out from the MST. Choose the edge with the lowest weight that connects a vertex among the MST vertices to a vertex outside the MST.
#
# 3. Add that edge and vertex to the MST.
#
# 4. Keep doing step 2 and 3 until all vertices belong to the MST.
#
# NOTE: Since the starting vertex is chosen at random, it is possible to have different edges included in the MST for the same graph, but the total edge weight of the MST will still have the same minimum value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🎯 Example to Understand
#
# Imagine cities:
#
# Prim’s → Connect all cities with minimum cost (like laying cables)
#
# Dijkstra’s → Find shortest route from City A to all others
#
# ✅ Final Summary
#
# Use Prim’s when you want a Minimum Spanning Tree
#
# Use Dijkstra’s when you want Shortest Paths from a source

# %% [markdown]
# #Q1). Min Cost to Connect All Points
#
# You are given an array points representing integer coordinates of some points on a 2D-plane, where points[i] = [xi, yi].
#
# The cost of connecting two points [xi, yi] and [xj, yj] is the manhattan distance between them: |xi - xj| + |yi - yj|, where |val| denotes the absolute value of val.
#
# Return the minimum cost to make all points connected. All points are connected if there is exactly one simple path between any two points.
#
#
#
# Example 1:
#
# ![image.png](data:image/png;base64,...)
#
# Input: points = [[0,0],[2,2],[3,10],[5,2],[7,0]]
#
# Output: 20
#
# ![image.png](data:image/png;base64,...)
#
# Explanation:
#
# We can connect the points as shown above to get the minimum cost of 20.
# Notice that there is a unique path between every pair of points.

# %% [markdown]
# #Q2).  Network Delay Time
#
# You are given a network of n nodes, labeled from 1 to n. You are also given times, a list of travel times as directed edges times[i] = (ui, vi, wi), where ui is the source node, vi is the target node, and wi is the time it takes for a signal to travel from source to target.
#
# We will send a signal from a given node k. Return the minimum time it takes for all the n nodes to receive the signal. If it is impossible for all the n nodes to receive the signal, return -1.
#
#
#
# Example 1:
#
# ![image.png](data:image/png;base64,...)
#
#
#   Input: times = [[2,1,1],[2,3,1],[3,4,1]],   n = 4,   k = 2
#
# Output: 2
